# %%
def req(arr):
    if len(arr) == 1: return arr[0]
    else:
        # print(arr)
        return arr[-1] + req(arr[:-1])

# %%
test_arr = [2, 3, 4]
req(test_arr)
# Out:
# 9

# %%
list_sum(test_arr)
# Out:
# 14
